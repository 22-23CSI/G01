# %% [markdown]
# 500 PALABRAS

# %%
import random
import time
from math import pow

a=random.randint(2,10)

#Para encontrar el mcd de un número
def gcd(a,b):
    if a<b:
        return gcd(b,a)
    elif a%b==0:
        return b
    else:
        return gcd(b,a%b)

#For key generation i.e. large random number
def gen_key(q):
    key= random.randint(pow(10,20),q)
    while gcd(q,key)!=1:
        key=random.randint(pow(10,20),q)
    return key

def power(a,b,c):
    x=1
    y=a
    while b>0:
        if b%2==0:
            x=(x*y)%c;
        y=(y*y)%c
        b=int(b/2)
    return x%c

#For asymetric encryption
def encryption(msg,q,h,g):
    ct=[]
    k=gen_key(q)
    s=power(h,k,q)
    p=power(g,k,q)
    for i in range(0,len(msg)):
        ct.append(msg[i])
    print("g^k used= ",p)
    print("Llave privada es  ",s)
    for i in range(0,len(ct)):
        ct[i]=s*ord(ct[i])
    return ct,p

#For decryption
def decryption(ct,p,key,q):
    pt=[]
    h=power(p,key,q)
    for i in range(0,len(ct)):
        pt.append(chr(int(ct[i]/h)))
    return pt


start_file = time.time()
f = open('500w.txt', 'r')
msg = f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (500 palabras): " + format(end_file-start_file))
print("\r")

start_clave = time.time()
q=random.randint(pow(10,20),pow(10,50))
g=random.randint(2,q)
key=gen_key(q)
h=power(g,key,q)
end_clave = time.time()

print("Llave publica es =",h)
print("Tiempo de claves para el archivo (500 palabras): " + format(end_clave-start_clave))
print("\r")

start_encrypt = time.time()
ct,p=encryption(msg,q,h,g)
print("Mensaje Original=",msg)
print("Mensaje Encriptado=",ct)
end_encrypt = time.time()
print("Tiempo de encriptacion para el archivo (500 palabras): " + format(end_encrypt-start_encrypt))
print("\r")

start_uncrypt = time.time()
pt=decryption(ct,p,key,q)
d_msg=''.join(pt)
end_uncrypt = time.time()
print("Decryted Message=",d_msg)
print("Tiempo de desencriptación para el archivo (500 palabras): " + format(end_uncrypt-start_uncrypt))
print("\r")
# Out:
# Tiempo de lectura para el archivo (500 palabras): 0.0002987384796142578
#
# Llave publica es = 22565802119720637172693743965618999779019823720813
# Tiempo de claves para el archivo (500 palabras): 0.0005598068237304688
#
# g^k used=  52647228432297290212633594476725478841654634510178
# Llave privada es   45779332373972860210546659743027249806058418187461
# ...

# %% [markdown]
# 1K PALABRAS

# %%
import random
from math import pow

a=random.randint(2,10)

#Para encontrar el mcd de un número
def gcd(a,b):
    if a<b:
        return gcd(b,a)
    elif a%b==0:
        return b
    else:
        return gcd(b,a%b)

#For key generation i.e. large random number
def gen_key(q):
    key= random.randint(pow(10,20),q)
    while gcd(q,key)!=1:
        key=random.randint(pow(10,20),q)
    return key

def power(a,b,c):
    x=1
    y=a
    while b>0:
        if b%2==0:
            x=(x*y)%c;
        y=(y*y)%c
        b=int(b/2)
    return x%c

#For asymetric encryption
def encryption(msg,q,h,g):
    ct=[]
    k=gen_key(q)
    s=power(h,k,q)
    p=power(g,k,q)
    for i in range(0,len(msg)):
        ct.append(msg[i])
    print("g^k used= ",p)
    print("Llave privada es  ",s)
    for i in range(0,len(ct)):
        ct[i]=s*ord(ct[i])
    return ct,p

#For decryption
def decryption(ct,p,key,q):
    pt=[]
    h=power(p,key,q)
    for i in range(0,len(ct)):
        pt.append(chr(int(ct[i]/h)))
    return pt


start_file = time.time()
f = open('1kw.txt', 'r')
msg = f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (1000 palabras): " + format(end_file-start_file))
print("\r")

start_clave = time.time()
q=random.randint(pow(10,20),pow(10,50))
g=random.randint(2,q)
key=gen_key(q)
h=power(g,key,q)
end_clave = time.time()

print("Llave publica es =",h)
print("Tiempo de claves para el archivo (1000 palabras): " + format(end_clave-start_clave))
print("\r")

start_encrypt = time.time()
ct,p=encryption(msg,q,h,g)
print("Mensaje Original=",msg)
print("Mensaje Encriptado=",ct)
end_encrypt = time.time()
print("Tiempo de encriptacion para el archivo (1000 palabras): " + format(end_encrypt-start_encrypt))
print("\r")

start_uncrypt = time.time()
pt=decryption(ct,p,key,q)
d_msg=''.join(pt)
end_uncrypt = time.time()
print("Decryted Message=",d_msg)
print("Tiempo de desencriptación para el archivo (1000 palabras): " + format(end_uncrypt-start_uncrypt))
print("\r")
# Out:
# Tiempo de lectura para el archivo (1000 palabras): 0.0002129077911376953
#
# Llave publica es = 2389727989681588805348820450596881327450258770065
# Tiempo de claves para el archivo (1000 palabras): 0.000396728515625
#
# g^k used=  454068053053652005395302394438240621096938192886
# Llave privada es   1102138564645391093793182104132022973032822501544
# ...

# %% [markdown]
# 5K PALABRAS

# %%
import random
from math import pow

a=random.randint(2,10)

#Para encontrar el mcd de un número
def gcd(a,b):
    if a<b:
        return gcd(b,a)
    elif a%b==0:
        return b
    else:
        return gcd(b,a%b)

#For key generation i.e. large random number
def gen_key(q):
    key= random.randint(pow(10,20),q)
    while gcd(q,key)!=1:
        key=random.randint(pow(10,20),q)
    return key

def power(a,b,c):
    x=1
    y=a
    while b>0:
        if b%2==0:
            x=(x*y)%c;
        y=(y*y)%c
        b=int(b/2)
    return x%c

#For asymetric encryption
def encryption(msg,q,h,g):
    ct=[]
    k=gen_key(q)
    s=power(h,k,q)
    p=power(g,k,q)
    for i in range(0,len(msg)):
        ct.append(msg[i])
    print("g^k used= ",p)
    print("Llave privada es  ",s)
    for i in range(0,len(ct)):
        ct[i]=s*ord(ct[i])
    return ct,p

#For decryption
def decryption(ct,p,key,q):
    pt=[]
    h=power(p,key,q)
    for i in range(0,len(ct)):
        pt.append(chr(int(ct[i]/h)))
    return pt


start_file = time.time()
f = open('5kw.txt', 'r')
msg = f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (5000 palabras): " + format(end_file-start_file))
print("\r")

start_clave = time.time()
q=random.randint(pow(10,20),pow(10,50))
g=random.randint(2,q)
key=gen_key(q)
h=power(g,key,q)
end_clave = time.time()

print("Llave publica es =",h)
print("Tiempo de claves para el archivo (5000 palabras): " + format(end_clave-start_clave))
print("\r")

start_encrypt = time.time()
ct,p=encryption(msg,q,h,g)
print("Mensaje Original=",msg)
print("Mensaje Encriptado=",ct)
end_encrypt = time.time()
print("Tiempo de encriptacion para el archivo (5000 palabras): " + format(end_encrypt-start_encrypt))
print("\r")

start_uncrypt = time.time()
pt=decryption(ct,p,key,q)
d_msg=''.join(pt)
end_uncrypt = time.time()
print("Decryted Message=",d_msg)
print("Tiempo de desencriptación para el archivo (5000 palabras): " + format(end_uncrypt-start_uncrypt))
print("\r")
# Out:
# Tiempo de lectura para el archivo (5000 palabras): 0.0003399848937988281
#
# Llave publica es = 2401140704259955974313355348631306512306027940514
# Tiempo de claves para el archivo (5000 palabras): 0.0006804466247558594
#
# g^k used=  4013667108442670636646991642079971168357414160750
# Llave privada es   32707385401289868763984179363638115889774704774988
# Mensaje Original= hola 5k dolor sit amet, consectetur adipiscing elit. Phasellus iaculis viverra urna. Nullam volutpat nulla tellus, id placerat libero ornare eget. Cras a varius justo. Aenean varius luctus neque id maximus. Duis et dui sed augue ultricies porta. Sed euismod tristique vulputate. Mauris ultricies ipsum ipsum, sit amet fringilla urna malesuada quis.
#
# ...

# %% [markdown]
# 10K PALABRAS

# %%
import random
from math import pow

a=random.randint(2,10)

#Para encontrar el mcd de un número
def gcd(a,b):
    if a<b:
        return gcd(b,a)
    elif a%b==0:
        return b
    else:
        return gcd(b,a%b)

#For key generation i.e. large random number
def gen_key(q):
    key= random.randint(pow(10,20),q)
    while gcd(q,key)!=1:
        key=random.randint(pow(10,20),q)
    return key

def power(a,b,c):
    x=1
    y=a
    while b>0:
        if b%2==0:
            x=(x*y)%c;
        y=(y*y)%c
        b=int(b/2)
    return x%c

#For asymetric encryption
def encryption(msg,q,h,g):
    ct=[]
    k=gen_key(q)
    s=power(h,k,q)
    p=power(g,k,q)
    for i in range(0,len(msg)):
        ct.append(msg[i])
    print("g^k used= ",p)
    print("Llave privada es  ",s)
    for i in range(0,len(ct)):
        ct[i]=s*ord(ct[i])
    return ct,p

#For decryption
def decryption(ct,p,key,q):
    pt=[]
    h=power(p,key,q)
    for i in range(0,len(ct)):
        pt.append(chr(int(ct[i]/h)))
    return pt


start_file = time.time()
f = open('10kw.txt', 'r')
msg = f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (10000 palabras): " + format(end_file-start_file))
print("\r")

start_clave = time.time()
q=random.randint(pow(10,20),pow(10,50))
g=random.randint(2,q)
key=gen_key(q)
h=power(g,key,q)
end_clave = time.time()

print("Llave publica es =",h)
print("Tiempo de claves para el archivo (10000 palabras): " + format(end_clave-start_clave))
print("\r")

start_encrypt = time.time()
ct,p=encryption(msg,q,h,g)
#print("Mensaje Original=",msg)
#print("Mensaje Encriptado=",ct)
end_encrypt = time.time()
print("Tiempo de encriptacion para el archivo (10000 palabras): " + format(end_encrypt-start_encrypt))
print("\r")

start_uncrypt = time.time()
pt=decryption(ct,p,key,q)
d_msg=''.join(pt)
end_uncrypt = time.time()
print("Decryted Message=",d_msg)
print("Tiempo de desencriptación para el archivo (10000 palabras): " + format(end_uncrypt-start_uncrypt))
print("\r")
# Out:
# Tiempo de lectura para el archivo (10000 palabras): 0.00042438507080078125
#
# Llave publica es = 84120367310868059366800145702443531377347288493562
# Tiempo de claves para el archivo (10000 palabras): 0.0004210472106933594
#
# g^k used=  89965273146041173881596304509454511912238559259514
# Llave privada es   60519689238323183374307737434629724608565994853844
# Tiempo de encriptacion para el archivo (10000 palabras): 0.02679729461669922
#
# Decryted Message= hola 10k dolor sit amet, consectetur adipiscing elit. Phasellus iaculis viverra urna. Nullam volutpat nulla tellus, id placerat libero ornare eget. Cras a varius justo. Aenean varius luctus neque id maximus. Duis et dui sed augue ultricies porta. Sed euismod tristique vulputate. Mauris ultricies ipsum ipsum, sit amet fringilla urna malesuada quis.
#
# ...

# %% [markdown]
# 100K PALABRAS

# %%
import random
from math import pow

a=random.randint(2,10)

#Para encontrar el mcd de un número
def gcd(a,b):
    if a<b:
        return gcd(b,a)
    elif a%b==0:
        return b
    else:
        return gcd(b,a%b)

#For key generation i.e. large random number
def gen_key(q):
    key= random.randint(pow(10,20),q)
    while gcd(q,key)!=1:
        key=random.randint(pow(10,20),q)
    return key

def power(a,b,c):
    x=1
    y=a
    while b>0:
        if b%2==0:
            x=(x*y)%c;
        y=(y*y)%c
        b=int(b/2)
    return x%c

#For asymetric encryption
def encryption(msg,q,h,g):
    ct=[]
    k=gen_key(q)
    s=power(h,k,q)
    p=power(g,k,q)
    for i in range(0,len(msg)):
        ct.append(msg[i])
    print("g^k used= ",p)
    print("Llave privada es  ",s)
    for i in range(0,len(ct)):
        ct[i]=s*ord(ct[i])
    return ct,p

#For decryption
def decryption(ct,p,key,q):
    pt=[]
    h=power(p,key,q)
    for i in range(0,len(ct)):
        pt.append(chr(int(ct[i]/h)))
    return pt


start_file = time.time()
f = open('100kw.txt', 'r')
msg = f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (100000 palabras): " + format(end_file-start_file))
print("\r")

start_clave = time.time()
q=random.randint(pow(10,20),pow(10,50))
g=random.randint(2,q)
key=gen_key(q)
h=power(g,key,q)
end_clave = time.time()

print("Llave publica es =",h)
print("Tiempo de claves para el archivo (100000 palabras): " + format(end_clave-start_clave))
print("\r")

start_encrypt = time.time()
ct,p=encryption(msg,q,h,g)
#print("Mensaje Original=",msg)
#print("Mensaje Encriptado=",ct)
end_encrypt = time.time()
print("Tiempo de encriptacion para el archivo (100000 palabras): " + format(end_encrypt-start_encrypt))
print("\r")

start_uncrypt = time.time()
pt=decryption(ct,p,key,q)
d_msg=''.join(pt)
end_uncrypt = time.time()
print("Decryted Message=",d_msg)
print("Tiempo de desencriptación para el archivo (100000 palabras): " + format(end_uncrypt-start_uncrypt))
print("\r")
# Out:
# Tiempo de lectura para el archivo (100000 palabras): 0.0009114742279052734
#
# Llave publica es = 48226468431569178292864267106155893954465426256205
# Tiempo de claves para el archivo (100000 palabras): 0.0005788803100585938
#
# g^k used=  6899517664577835487798052262746007694718657540983
# Llave privada es   60726962952225673190572818381344140724496718459705
# Tiempo de encriptacion para el archivo (100000 palabras): 0.21211719512939453
#
# Decryted Message= Lorem ipsum dolor sit amet. Aut itaque tempore et ullam unde qui molestiae explicabo ut nihil eligendi et eveniet fuga est accusantium odit ut quibusdam tempora! Ab voluptatem ullam in illum omnis aut consequuntur galisum et libero aliquam. Eum quae ullam et voluptatum repellendus sed voluptatem iure ad itaque autem id iure ipsa. Sit exercitationem voluptatem ut iusto expedita est quas Quis eum illo nihil qui modi error aut nisi cumque.
#
# ...

# %% [markdown]
# 1M PALABRAS

# %%
import random
from math import pow

a=random.randint(2,10)

#Para encontrar el mcd de un número
def gcd(a,b):
    if a<b:
        return gcd(b,a)
    elif a%b==0:
        return b
    else:
        return gcd(b,a%b)

#For key generation i.e. large random number
def gen_key(q):
    key= random.randint(pow(10,20),q)
    while gcd(q,key)!=1:
        key=random.randint(pow(10,20),q)
    return key

def power(a,b,c):
    x=1
    y=a
    while b>0:
        if b%2==0:
            x=(x*y)%c;
        y=(y*y)%c
        b=int(b/2)
    return x%c

#For asymetric encryption
def encryption(msg,q,h,g):
    ct=[]
    k=gen_key(q)
    s=power(h,k,q)
    p=power(g,k,q)
    for i in range(0,len(msg)):
        ct.append(msg[i])
    print("g^k used= ",p)
    print("Llave privada es  ",s)
    for i in range(0,len(ct)):
        ct[i]=s*ord(ct[i])
    return ct,p

#For decryption
def decryption(ct,p,key,q):
    pt=[]
    h=power(p,key,q)
    for i in range(0,len(ct)):
        pt.append(chr(int(ct[i]/h)))
    return pt


start_file = time.time()
f = open('1mw.txt', 'r')
msg = f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (1000000 palabras): " + format(end_file-start_file))
print("\r")

start_clave = time.time()
q=random.randint(pow(10,20),pow(10,50))
g=random.randint(2,q)
key=gen_key(q)
h=power(g,key,q)
end_clave = time.time()

print("Llave publica es =",h)
print("Tiempo de claves para el archivo (1000000 palabras): " + format(end_clave-start_clave))
print("\r")

start_encrypt = time.time()
ct,p=encryption(msg,q,h,g)
#print("Mensaje Original=",msg)
#print("Mensaje Encriptado=",ct)
end_encrypt = time.time()
print("Tiempo de encriptacion para el archivo (1000000 palabras): " + format(end_encrypt-start_encrypt))
print("\r")

start_uncrypt = time.time()
pt=decryption(ct,p,key,q)
d_msg=''.join(pt)
end_uncrypt = time.time()
#print("Decryted Message=",d_msg)
print("Tiempo de desencriptación para el archivo (1000000 palabras): " + format(end_uncrypt-start_uncrypt))
print("\r")
# Out:
# Tiempo de lectura para el archivo (1000000 palabras): 0.007444620132446289
#
# Llave publica es = 36312813391888777744599068237081135108846875955054
# Tiempo de claves para el archivo (1000000 palabras): 0.0004367828369140625
#
# g^k used=  91220556464860570807134187855062761648784316351398
# Llave privada es   83597766306636786434970252638080070176734387669245
# Tiempo de encriptacion para el archivo (1000000 palabras): 2.84466552734375
#
# Tiempo de desencriptación para el archivo (1000000 palabras): 4.58044695854187
