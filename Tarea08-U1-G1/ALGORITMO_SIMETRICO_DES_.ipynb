# %%
pip install pycryptodome
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.3 MB 5.3 MB/s
# ...

# %%
import binascii
import time
import random
from Crypto.Cipher import DES 
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad, unpad

# %% [markdown]
# 500 PALABRAS

# %%
start_file = time.time()
f = open('500w.txt', 'r')
data=f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (500 palabras): " + format(end_file-start_file))
print("\r")

start_encrypt = time.time() 

valor=random.randint(10000000,12345678)
numero=str(valor)
key= bytes(numero,'utf-8')


cipher1=DES.new(key,DES.MODE_CFB,key)
data1=data.encode()
msg=cipher1.encrypt(data1)
end_encrypt = time.time()
print("La llave usada es: " + numero)
print("Tiempo de encriptacion para el archivo (500 palabras): " + format(end_encrypt-start_encrypt))
print(msg)
print("\r")



start_uncrypt = time.time()
cipher2=DES.new(key,DES.MODE_CFB,key)
msg2=cipher2.decrypt(msg).decode()
end_uncrypt = time.time()
print("Tiempo de des-encriptacion para el archivo (500 palabras): " + format(end_uncrypt-start_uncrypt))
print(msg2)
print("\r")
# Out:
# Tiempo de lectura para el archivo (500 palabras): 0.001194000244140625
#
# La llave usada es: 10053130
# Tiempo de encriptacion para el archivo (500 palabras): 0.0011417865753173828
# ...

# %% [markdown]
# 1K PALABRAS

# %%
start_file = time.time()
f = open('1kw.txt', 'r')
data=f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (1k palabras): " + format(end_file-start_file))
print("\r")

start_encrypt = time.time() 

valor=random.randint(10000000,12345678)
numero=str(valor)
key= bytes(numero,'utf-8')


cipher1=DES.new(key,DES.MODE_CFB,key)
data1=data.encode()
msg=cipher1.encrypt(data1)
end_encrypt = time.time()
print("La llave usada es: " + numero)
print("Tiempo de encriptacion para el archivo (1000 palabras): " + format(end_encrypt-start_encrypt))
print(msg)
print("\r")



start_uncrypt = time.time()
cipher2=DES.new(key,DES.MODE_CFB,key)
msg2=cipher2.decrypt(msg).decode()
end_uncrypt = time.time()
print("Tiempo de des-encriptacion para el archivo (1000 palabras): " + format(end_uncrypt-start_uncrypt))
print(msg2)
print("\r")
# Out:
# Tiempo de lectura para el archivo (1k palabras): 0.0002536773681640625
#
# La llave usada es: 12159216
# Tiempo de encriptacion para el archivo (1000 palabras): 0.0015919208526611328
# ...

# %% [markdown]
# 5K PALABRAS

# %%
start_file = time.time()
f = open('5kw.txt', 'r')
data=f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (5k palabras): " + format(end_file-start_file))
print("\r")

start_encrypt = time.time() 

valor=random.randint(10000000,12345678)
numero=str(valor)
key= bytes(numero,'utf-8')


cipher1=DES.new(key,DES.MODE_CFB,key)
data1=data.encode()
msg=cipher1.encrypt(data1)
end_encrypt = time.time()
print("La llave usada es: " + numero)
print("Tiempo de encriptacion para el archivo (5000 palabras): " + format(end_encrypt-start_encrypt))
print(msg)
print("\r")



start_uncrypt = time.time()
cipher2=DES.new(key,DES.MODE_CFB,key)
msg2=cipher2.decrypt(msg).decode()
end_uncrypt = time.time()
print("Tiempo de des-encriptacion para el archivo (5000 palabras): " + format(end_uncrypt-start_uncrypt))
print(msg2)
print("\r")
# Out:
# Tiempo de lectura para el archivo (5k palabras): 0.0012717247009277344
#
# La llave usada es: 10063079
# Tiempo de encriptacion para el archivo (5000 palabras): 0.006240367889404297
# ...

# %% [markdown]
# 10K PALABRAS

# %%
start_file = time.time()
f = open('10kw.txt', 'r')
data=f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (10k palabras): " + format(end_file-start_file))
print("\r")

start_encrypt = time.time() 

valor=random.randint(10000000,12345678)
numero=str(valor)
key= bytes(numero,'utf-8')


cipher1=DES.new(key,DES.MODE_CFB,key)
data1=data.encode()
msg=cipher1.encrypt(data1)
end_encrypt = time.time()
print("La llave usada es: " + numero)
print("Tiempo de encriptacion para el archivo (10000 palabras): " + format(end_encrypt-start_encrypt))
print(msg)
print("\r")



start_uncrypt = time.time()
cipher2=DES.new(key,DES.MODE_CFB,key)
msg2=cipher2.decrypt(msg).decode()
end_uncrypt = time.time()
print("Tiempo de des-encriptacion para el archivo (10000 palabras): " + format(end_uncrypt-start_uncrypt))
print(msg2)
print("\r")
# Out:
# Tiempo de lectura para el archivo (10k palabras): 0.0006093978881835938
#
# La llave usada es: 10422432
# Tiempo de encriptacion para el archivo (10000 palabras): 0.012012958526611328
# ...

# %% [markdown]
# 100K PALABRAS

# %%
start_file = time.time()
f = open('100kw.txt', 'r')
data=f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (100k palabras): " + format(end_file-start_file))
print("\r")

start_encrypt = time.time() 

valor=random.randint(10000000,12345678)
numero=str(valor)
key= bytes(numero,'utf-8')


cipher1=DES.new(key,DES.MODE_CFB,key)
data1=data.encode()
msg=cipher1.encrypt(data1)
end_encrypt = time.time()
print("La llave usada es: " + numero)
print("Tiempo de encriptacion para el archivo (100000 palabras): " + format(end_encrypt-start_encrypt))
print(msg)
print("\r")



start_uncrypt = time.time()
cipher2=DES.new(key,DES.MODE_CFB,key)
msg2=cipher2.decrypt(msg).decode()
end_uncrypt = time.time()
print("Tiempo de des-encriptacion para el archivo (100000 palabras): " + format(end_uncrypt-start_uncrypt))
#print(msg2)
print("\r")
# Out:
# Tiempo de lectura para el archivo (100k palabras): 0.0029599666595458984
#
# La llave usada es: 10345725
# Tiempo de encriptacion para el archivo (100000 palabras): 0.09890031814575195
# ...

# %%
start_file = time.time()
f = open('100kw.txt', 'r')
data=f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (100k palabras): " + format(end_file-start_file))
print("\r")

start_encrypt = time.time() 

valor=random.randint(10000000,12345678)
numero=str(valor)
key= bytes(numero,'utf-8')


cipher1=DES.new(key,DES.MODE_CFB,key)
data1=data.encode()
msg=cipher1.encrypt(data1)
end_encrypt = time.time()
print("La llave usada es: " + numero)
print("Tiempo de encriptacion para el archivo (100000 palabras): " + format(end_encrypt-start_encrypt))
#print(msg)
print("\r")



start_uncrypt = time.time()
cipher2=DES.new(key,DES.MODE_CFB,key)
msg2=cipher2.decrypt(msg).decode()
end_uncrypt = time.time()
print("Tiempo de des-encriptacion para el archivo (100000 palabras): " + format(end_uncrypt-start_uncrypt))
print(msg2)
print("\r")
# Out:
# Tiempo de lectura para el archivo (100k palabras): 0.0009801387786865234
#
# La llave usada es: 11554230
# Tiempo de encriptacion para el archivo (100000 palabras): 0.10056567192077637
#
# Tiempo de des-encriptacion para el archivo (100000 palabras): 0.0970001220703125
# Lorem ipsum dolor sit amet. Aut itaque tempore et ullam unde qui molestiae explicabo ut nihil eligendi et eveniet fuga est accusantium odit ut quibusdam tempora! Ab voluptatem ullam in illum omnis aut consequuntur galisum et libero aliquam. Eum quae ullam et voluptatum repellendus sed voluptatem iure ad itaque autem id iure ipsa. Sit exercitationem voluptatem ut iusto expedita est quas Quis eum illo nihil qui modi error aut nisi cumque.
#
# Sed omnis repellendus et quas veritatis non consequatur iste qui nihil voluptas et saepe pariatur sit aspernatur voluptas et consequatur consequatur. Sit nisi dolores ex recusandae rerum et tempore distinctio ex velit natus id atque deleniti sit reprehenderit nesciunt.
#
# ...

# %% [markdown]
# 1M PALABRAS

# %%
start_file = time.time()
f = open('1mw.txt', 'r')
data=f.read()
end_file = time.time()
print("Tiempo de lectura para el archivo (1M palabras): " + format(end_file-start_file))
print("\r")

start_encrypt = time.time() 

valor=random.randint(10000000,12345678)
numero=str(valor)
key= bytes(numero,'utf-8')


cipher1=DES.new(key,DES.MODE_CFB,key)
data1=data.encode()
msg=cipher1.encrypt(data1)
end_encrypt = time.time()
print("La llave usada es: " + numero)
print("Tiempo de encriptacion para el archivo (1000000 palabras): " + format(end_encrypt-start_encrypt))
#print(msg)
print("\r")



start_uncrypt = time.time()
cipher2=DES.new(key,DES.MODE_CFB,key)
msg2=cipher2.decrypt(msg).decode()
end_uncrypt = time.time()
print("Tiempo de des-encriptacion para el archivo (1000000 palabras): " + format(end_uncrypt-start_uncrypt))
#print(msg2)
print("\r")
# Out:
# Tiempo de lectura para el archivo (1M palabras): 0.007941007614135742
#
# La llave usada es: 10555832
# Tiempo de encriptacion para el archivo (1000000 palabras): 1.110422134399414
#
# Tiempo de des-encriptacion para el archivo (1000000 palabras): 1.0923621654510498
